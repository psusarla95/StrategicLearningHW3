# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import os

# %%
x_train = np.load('x_train.npy')
y_train = np.load('y_train.npy')
x_test = np.load('x_test.npy')
y_test = np.load('y_test.npy')

# %%
num_classes = 10
no_users = 20
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], -1))/255
x_test = np.reshape(x_test, (x_test.shape[0], -1))/255

# %%
x_train = x_train[:10000,:]
y_train = y_train[:10000,:]
x_test = x_test[:2000,:]
y_test = y_test[:2000,:]

# %%
class User:
    def __init__(self):
        self.W1 = tf.Variable(tf.random.truncated_normal([784,128], stddev=0.1))
        self.W2 = tf.Variable(tf.random.truncated_normal([128,64], stddev=0.1))
        self.W3 = tf.Variable(tf.random.truncated_normal([64,10], stddev=0.1))
        
        self.gW1 = tf.Variable(tf.random.truncated_normal([784,128], stddev=0.1))
        self.gW2 = tf.Variable(tf.random.truncated_normal([128,64], stddev=0.1))
        self.gW3 = tf.Variable(tf.random.truncated_normal([64,10], stddev=0.1))

        #self.lambda_W1 = tf.Variable(tf.zeros([784*128,1]))
        #self.lambda_W2 = tf.Variable(tf.zeros([128*64,1]))
        #self.lambda_W3 = tf.Variable(tf.zeros([64*10,1]))

    def neural_net(self, x):
        y1 = tf.nn.relu(tf.matmul(x, self.W1))
        y2 = tf.nn.relu(tf.matmul(y1, self.W2))
        ylogits = tf.matmul(y2, self.W3)
        return tf.nn.softmax(ylogits)

# %%
# mini-batch loss function.
def mini_batches(X, Y, mb_size):

    m = X.shape[0]
    perm = list(np.random.permutation(m))
    X_temp = X[perm,:]
    Y_temp = Y[perm,:].reshape((m, Y.shape[1]))
    
    X_r = tf.convert_to_tensor(X_temp[0:mb_size,:], dtype=np.float32)
    Y_r = tf.convert_to_tensor(Y_temp[0:mb_size,:], dtype=np.float32)
    return X_r,Y_r

# %%
# Cross-Entropy loss function.
def cross_entropy(y_pred, y_true):
    # Clip prediction values to avoid log(0) error.
    y_pred = tf.clip_by_value(y_pred, 1e-9, 1.)
    # Compute cross-entropy.
    return -tf.reduce_sum(y_true * tf.math.log(y_pred))

# %%
# Accuracy metric.
def accuracy(y_pred, y_true):
    # Predicted class is the index of highest score in prediction vector (i.e. argmax).
    correct_prediction = tf.equal(tf.argmax(y_pred, 1), tf.argmax(y_true, 1))
    return tf.reduce_mean(tf.cast(correct_prediction, tf.float32), axis=-1)

# %%
# Optimization process. 
def get_gradients(x, y, W1, W2, W3):
    # Variables to update, i.e. trainable variables.
    trainable_variables = [W1, W2, W3]
    
    with tf.GradientTape() as g:
        g.watch([W1,W2,W3])
        y1 = tf.nn.relu(tf.matmul(x, W1))
        y2 = tf.nn.relu(tf.matmul(y1, W2))
        ylogits = tf.matmul(y2, W3)
        pred = tf.nn.softmax(ylogits)
        loss = cross_entropy(pred, y) 
    
    # Compute gradients.
    gradients1, gradients2, gradients3  = g.gradient(loss, trainable_variables)
    
    return gradients1, gradients2, gradients3, loss

# %%
users = [User() for i in range(no_users)]
#rho = 20
eta = 100
central_modal = [tf.Variable(tf.random.truncated_normal([784*128,1], stddev=0.1)),\
                 tf.Variable(tf.random.truncated_normal([128*64,1], stddev=0.1)),\
                 tf.Variable(tf.random.truncated_normal([64*10,1], stddev=0.1))]

# %%
x_train_k = []
y_train_k = []
data_per_worker = int(x_train.shape[0]/no_users)
for i in range(no_users):
    first = i*data_per_worker
    last = first + data_per_worker
    x_train_k.append(x_train[first:last])
    y_train_k.append(y_train[first:last])

# %%
x_test = tf.convert_to_tensor(x_test, dtype=np.float32)
y_test = tf.convert_to_tensor(y_test, dtype=np.float32)

# %%
mb_size = 100
n_epochs = 500
lr = 0.001
n_localIter=10

# %%
Train_Acc = []
Test_Acc = []
acc_train = np.zeros([n_epochs,1])
acc_test = np.zeros([n_epochs,1])
total_loss = np.zeros([n_epochs,1])

for i in range(no_users):
    users[i].W1.assign(tf.reshape(central_modal[0],[784,128]))
    users[i].W2.assign(tf.reshape(central_modal[1],[128,64]))
    users[i].W3.assign(tf.reshape(central_modal[2],[64,10]))
            
for k in range(n_epochs):               
        batch_x = []
        batch_y = []
        for i in range(no_users):
            batch_xx , batch_yy = mini_batches(x_train_k[i],y_train_k[i],  mb_size)
            batch_x.append(batch_xx)
            batch_y.append(batch_yy) 
        for i in range(no_users):

            gradients1, gradients2, gradients3, loss= get_gradients(batch_x[i], batch_y[i], users[i].W1,\
                                                                        users[i].W2, users[i].W3)               
                                           
            users[i].gW1.assign(gradients1)
            users[i].gW2.assign(gradients2)
            users[i].gW3.assign(gradients3)
            total_loss[k] = total_loss[k] + loss
            
            
            ############
            
            w_1 = tf.reshape(users[i].W1,[784*128, 1])-1/(no_users)*lr*(tf.reshape(users[i].gW1,[784*128, 1]))
            w_2 = tf.reshape(users[i].W2,[128*64, 1]) -1/(no_users)*lr*(tf.reshape(users[i].gW2,[128*64, 1]) )
            w_3 = tf.reshape(users[i].W3,[64*10, 1]) -1/(no_users)*lr*(tf.reshape(users[i].gW3,[64*10, 1]) )
            
            users[i].W1.assign(tf.reshape(w_1,[784,128]))
            
            users[i].W2.assign(tf.reshape(w_2,[128,64]) )
            users[i].W3.assign(tf.reshape(w_3,[64,10]) )
            
            ##################
        
        if k%n_localIter==0:
            temp11 = 0
            temp21 = 0
            temp31 = 0              
            for i in range(no_users):           
                temp11 = temp11 + tf.reshape(users[i].W1,[784*128, 1])

                temp21 = temp21 + tf.reshape(users[i].W2,[128*64, 1]) 

                temp31 = temp31 + tf.reshape(users[i].W3,[64*10, 1]) 

            # Update central model 1
            #central_modal[0] = 1/(no_users)*(temp11)
            #central_modal[1] = 1/(no_users)*(temp21)
            #central_modal[2] = 1/(no_users)*(temp31)
            
            # Update central model 2
            central_modal[0] = central_modal[0]-1/(no_users)*lr*(temp11)
            central_modal[1] = central_modal[1]-1/(no_users)*lr*(temp21)
            central_modal[2] = central_modal[2]-1/(no_users)*lr*(temp31)

            for i in range(no_users):

                users[i].W1.assign(tf.reshape(central_modal[0],[784,128]))
                users[i].W2.assign(tf.reshape(central_modal[1],[128,64]))
                users[i].W3.assign(tf.reshape(central_modal[2],[64,10]))       
        
        train_acc = []
        test_acc = []
        for j in range(no_users):  
            train_pred = users[j].neural_net(batch_x[j])
            train_acc.append(accuracy(train_pred, batch_y[j]))
            test_pred = users[j].neural_net(x_test)
            test_acc.append(accuracy(test_pred, y_test))
        avgAcc_Train = np.mean(train_acc)
        avgAcc_Test = np.mean(test_acc)
        print('Train accuracy', avgAcc_Train)
        print('Test accuracy',avgAcc_Test)
        acc_train[k] = avgAcc_Train
        acc_test[k] = avgAcc_Test
# Out:
# Train accuracy 0.08150001
# Test accuracy 0.07700001
# Train accuracy 0.084
# Test accuracy 0.07865001
# Train accuracy 0.08050001
# Test accuracy 0.0786
# Train accuracy 0.0935
# Test accuracy 0.078575
# Train accuracy 0.076000005
# Test accuracy 0.07875
# Train accuracy 0.089499995
# Test accuracy 0.078925
# Train accuracy 0.087000005
# Test accuracy 0.079224996
# Train accuracy 0.0855
# Test accuracy 0.079725
# Train accuracy 0.1005
# Test accuracy 0.080074996
# Train accuracy 0.089
# Test accuracy 0.08049999
# Train accuracy 0.085499994
# Test accuracy 0.080000006
# Train accuracy 0.099
# Test accuracy 0.080350004
# Train accuracy 0.103
# Test accuracy 0.08104999
# Train accuracy 0.089999996
# Test accuracy 0.081925
# Train accuracy 0.095000006
# Test accuracy 0.08302499
# Train accuracy 0.0935
# Test accuracy 0.08384999
# Train accuracy 0.083000004
# Test accuracy 0.085
# Train accuracy 0.1025
# Test accuracy 0.085775
# Train accuracy 0.103
# Test accuracy 0.086349994
# Train accuracy 0.090500005
# Test accuracy 0.08742499
# Train accuracy 0.1015
# Test accuracy 0.08850001
# Train accuracy 0.097
# Test accuracy 0.08915
# Train accuracy 0.08400001
# Test accuracy 0.090124995
# Train accuracy 0.099
# Test accuracy 0.091125
# Train accuracy 0.1
# Test accuracy 0.092025
# Train accuracy 0.096499994
# Test accuracy 0.093075
# Train accuracy 0.110000014
# Test accuracy 0.09460001
# Train accuracy 0.11149999
# Test accuracy 0.09565
# Train accuracy 0.1015
# Test accuracy 0.09702499
# Train accuracy 0.1005
# Test accuracy 0.09855
# Train accuracy 0.1015
# Test accuracy 0.1005
# Train accuracy 0.12099998
# Test accuracy 0.1023
# Train accuracy 0.10949999
# Test accuracy 0.103975
# Train accuracy 0.115499996
# Test accuracy 0.1054
# Train accuracy 0.11999999
# Test accuracy 0.1069
# Train accuracy 0.11450001
# Test accuracy 0.10792501
# Train accuracy 0.115499996
# Test accuracy 0.109625
# Train accuracy 0.12750003
# Test accuracy 0.111150004
# Train accuracy 0.124999985
# Test accuracy 0.11252501
# Train accuracy 0.117499985
# Test accuracy 0.113775
# Train accuracy 0.121999994
# Test accuracy 0.114999995
# Train accuracy 0.12599999
# Test accuracy 0.11565
# Train accuracy 0.13
# Test accuracy 0.116825
# Train accuracy 0.1285
# Test accuracy 0.118575014
# Train accuracy 0.13400002
# Test accuracy 0.120599985
# Train accuracy 0.127
# Test accuracy 0.12205
# Train accuracy 0.142
# Test accuracy 0.12392501
# Train accuracy 0.13249998
# Test accuracy 0.125225
# Train accuracy 0.136
# Test accuracy 0.1271
# Train accuracy 0.1495
# Test accuracy 0.12872502
# Train accuracy 0.148
# Test accuracy 0.12899998
# Train accuracy 0.137
# Test accuracy 0.131025
# Train accuracy 0.142
# Test accuracy 0.13237499
# Train accuracy 0.1505
# Test accuracy 0.1341
# Train accuracy 0.14050001
# Test accuracy 0.13545
# Train accuracy 0.14750001
# Test accuracy 0.136875
# Train accuracy 0.15
# Test accuracy 0.13862501
# Train accuracy 0.1425
# Test accuracy 0.1403
# Train accuracy 0.14649999
# Test accuracy 0.142025
# Train accuracy 0.16099998
# Test accuracy 0.144425
# Train accuracy 0.16250001
# Test accuracy 0.145
# Train accuracy 0.16700003
# Test accuracy 0.14742501
# Train accuracy 0.1715
# Test accuracy 0.14979999
# Train accuracy 0.1585
# Test accuracy 0.15159999
# Train accuracy 0.1755
# Test accuracy 0.15327498
# Train accuracy 0.1715
# Test accuracy 0.155
# Train accuracy 0.164
# Test accuracy 0.15734999
# Train accuracy 0.16450003
# Test accuracy 0.15885001
# Train accuracy 0.16350001
# Test accuracy 0.16087501
# Train accuracy 0.18200001
# Test accuracy 0.163175
# Train accuracy 0.1755
# Test accuracy 0.164
# Train accuracy 0.17600003
# Test accuracy 0.1666
# Train accuracy 0.18200001
# Test accuracy 0.1691
# Train accuracy 0.1755
# Test accuracy 0.17095001
# Train accuracy 0.18250002
# Test accuracy 0.173275
# Train accuracy 0.18800002
# Test accuracy 0.17525001
# Train accuracy 0.18800001
# Test accuracy 0.17715001
# Train accuracy 0.187
# Test accuracy 0.178675
# Train accuracy 0.19250001
# Test accuracy 0.18079999
# Train accuracy 0.19450001
# Test accuracy 0.1831
# Train accuracy 0.1905
# Test accuracy 0.181
# Train accuracy 0.18850002
# Test accuracy 0.18429999
# Train accuracy 0.20050001
# Test accuracy 0.186575
# Train accuracy 0.20250002
# Test accuracy 0.19012499
# Train accuracy 0.2115
# Test accuracy 0.19240001
# Train accuracy 0.20600002
# Test accuracy 0.19444999
# Train accuracy 0.19350001
# Test accuracy 0.19645001
# Train accuracy 0.197
# Test accuracy 0.198275
# Train accuracy 0.223
# Test accuracy 0.19995001
# Train accuracy 0.21849999
# Test accuracy 0.20162502
# Train accuracy 0.19800001
# Test accuracy 0.20250002
# Train accuracy 0.225
# Test accuracy 0.203075
# Train accuracy 0.22349997
# Test accuracy 0.20485
# Train accuracy 0.22349998
# Test accuracy 0.20645002
# Train accuracy 0.226
# Test accuracy 0.207775
# Train accuracy 0.22350001
# Test accuracy 0.210125
# Train accuracy 0.21200001
# Test accuracy 0.21182501
# Train accuracy 0.225
# Test accuracy 0.21369998
# Train accuracy 0.2165
# Test accuracy 0.215
# Train accuracy 0.23749998
# Test accuracy 0.21607502
# Train accuracy 0.246
# Test accuracy 0.21849999
# Train accuracy 0.23099999
# Test accuracy 0.219275
# Train accuracy 0.24999997
# Test accuracy 0.22
# Train accuracy 0.245
# Test accuracy 0.22102499
# Train accuracy 0.222
# Test accuracy 0.222225
# Train accuracy 0.24249999
# Test accuracy 0.22354999
# Train accuracy 0.2345
# Test accuracy 0.225
# Train accuracy 0.265
# Test accuracy 0.22639999
# Train accuracy 0.26199996
# Test accuracy 0.51795
# Train accuracy 0.5765
# Test accuracy 0.518075
# Train accuracy 0.5605
# Test accuracy 0.51909995
# Train accuracy 0.57199997
# Test accuracy 0.51952493
# Train accuracy 0.587
# Test accuracy 0.51954997
# Train accuracy 0.5615
# Test accuracy 0.521
# Train accuracy 0.5705
# Test accuracy 0.5224501
# Train accuracy 0.5535
# Test accuracy 0.52345
# Train accuracy 0.5685
# Test accuracy 0.524675
# Train accuracy 0.5615
# Test accuracy 0.52522504
# Train accuracy 0.5805
# Test accuracy 0.5252
# Train accuracy 0.551
# Test accuracy 0.526475
# Train accuracy 0.58
# Test accuracy 0.527725
# Train accuracy 0.573
# Test accuracy 0.52865
# Train accuracy 0.567
# Test accuracy 0.5296
# Train accuracy 0.5845
# Test accuracy 0.5299999
# Train accuracy 0.56649995
# Test accuracy 0.53195
# Train accuracy 0.584
# Test accuracy 0.53247505
# Train accuracy 0.602
# Test accuracy 0.533625
# Train accuracy 0.587
# Test accuracy 0.53465
# Train accuracy 0.5925001
# Test accuracy 0.535725
# Train accuracy 0.59299994
# Test accuracy 0.535925
# Train accuracy 0.5825
# Test accuracy 0.53655
# Train accuracy 0.5885001
# Test accuracy 0.53814995
# Train accuracy 0.5975
# Test accuracy 0.53805006
# Train accuracy 0.5645
# Test accuracy 0.5389999
# Train accuracy 0.575
# Test accuracy 0.54055005
# Train accuracy 0.59499997
# Test accuracy 0.54125
# Train accuracy 0.5985
# Test accuracy 0.541475
# Train accuracy 0.5985
# Test accuracy 0.54190004
# Train accuracy 0.57500005
# Test accuracy 0.5425
# Train accuracy 0.57850003
# Test accuracy 0.544025
# Train accuracy 0.5875
# Test accuracy 0.54422504
# Train accuracy 0.584
# Test accuracy 0.5452
# Train accuracy 0.606
# Test accuracy 0.545575
# Train accuracy 0.581
# Test accuracy 0.545
# Train accuracy 0.6015
# Test accuracy 0.54565006
# Train accuracy 0.60349995
# Test accuracy 0.54700005
# Train accuracy 0.5895
# Test accuracy 0.54767495
# Train accuracy 0.5975
# Test accuracy 0.548925
# Train accuracy 0.5985
# Test accuracy 0.549425
# Train accuracy 0.6165
# Test accuracy 0.5501001
# Train accuracy 0.5914999
# Test accuracy 0.5516
# Train accuracy 0.6015
# Test accuracy 0.55237496
# Train accuracy 0.615
# Test accuracy 0.55270004
# Train accuracy 0.6105
# Test accuracy 0.55249995
# Train accuracy 0.5875
# Test accuracy 0.554425
# Train accuracy 0.61
# Test accuracy 0.55475
# Train accuracy 0.6025001
# Test accuracy 0.556275
# Train accuracy 0.61
# Test accuracy 0.557425
# Train accuracy 0.614
# Test accuracy 0.5586
# Train accuracy 0.616
# Test accuracy 0.55955
# Train accuracy 0.6015
# Test accuracy 0.560675
# Train accuracy 0.6
# Test accuracy 0.56115
# Train accuracy 0.6090001
# Test accuracy 0.56149995
# Train accuracy 0.6135
# Test accuracy 0.56149995
# Train accuracy 0.6095
# Test accuracy 0.562475
# Train accuracy 0.6055
# Test accuracy 0.5634
# Train accuracy 0.6065
# Test accuracy 0.564175
# Train accuracy 0.59299994
# Test accuracy 0.564475
# Train accuracy 0.61800003
# Test accuracy 0.565425
# Train accuracy 0.627
# Test accuracy 0.56677496
# Train accuracy 0.6125
# Test accuracy 0.56754994
# Train accuracy 0.6194999
# Test accuracy 0.56842494
# Train accuracy 0.6125
# Test accuracy 0.569075
# Train accuracy 0.613
# Test accuracy 0.5705001
# Train accuracy 0.61
# Test accuracy 0.57052505
# Train accuracy 0.606
# Test accuracy 0.5717751
# Train accuracy 0.62
# Test accuracy 0.5726
# Train accuracy 0.6135
# Test accuracy 0.573225
# Train accuracy 0.6165
# Test accuracy 0.5735
# Train accuracy 0.61050004
# Test accuracy 0.57395
# Train accuracy 0.62600005
# Test accuracy 0.574575
# Train accuracy 0.624
# Test accuracy 0.575225
# Train accuracy 0.61149997
# Test accuracy 0.57565004
# Train accuracy 0.6235
# Test accuracy 0.57550013
# Train accuracy 0.629
# Test accuracy 0.577875
# Train accuracy 0.6295
# Test accuracy 0.578325
# Train accuracy 0.635
# Test accuracy 0.578975
# Train accuracy 0.64
# Test accuracy 0.579525
# Train accuracy 0.6275
# Test accuracy 0.57965
# Train accuracy 0.638
# Test accuracy 0.58027494
# Train accuracy 0.621
# Test accuracy 0.58082503
# Train accuracy 0.6315
# Test accuracy 0.581725
# Train accuracy 0.63250005
# Test accuracy 0.58195
# Train accuracy 0.6345001
# Test accuracy 0.58199996
# Train accuracy 0.626
# Test accuracy 0.58295006
# Train accuracy 0.62399995
# Test accuracy 0.58367497
# Train accuracy 0.633
# Test accuracy 0.58475
# Train accuracy 0.6355001
# Test accuracy 0.585375
# Train accuracy 0.6330001
# Test accuracy 0.58632505
# Train accuracy 0.636
# Test accuracy 0.58687496
# Train accuracy 0.6325
# Test accuracy 0.58725
# Train accuracy 0.623
# Test accuracy 0.58755004
# Train accuracy 0.646
# Test accuracy 0.58839995
# Train accuracy 0.6355
# Test accuracy 0.587
# Train accuracy 0.624
# Test accuracy 0.58765
# Train accuracy 0.62850004
# Test accuracy 0.588325
# Train accuracy 0.62799996
# Test accuracy 0.5897249
# Train accuracy 0.63250005
# Test accuracy 0.59009993
# Train accuracy 0.6365
# Test accuracy 0.5907999
# Train accuracy 0.62900007
# Test accuracy 0.59124994
# Train accuracy 0.663
# Test accuracy 0.59167504
# Train accuracy 0.6385
# Test accuracy 0.59277505
# Train accuracy 0.642
# Test accuracy 0.59309995

# %%
acc_test[-1]
# Out:
# array([0.58860004])

# %%
import matplotlib.pyplot as plt

# Create plots with pre-defined labels.
fig, ax = plt.subplots()
ax.plot(range(n_epochs), acc_train, 'r-*', label='Average Train Accuracy')
ax.plot(range(n_epochs), acc_test, 'b-*', label='Average Test Accuracy')

legend = ax.legend(loc='lower right', shadow=True, fontsize='x-large')

plt.show()

# %%
np.save('acc_train_miniSGD', acc_train)
np.save('acc_test_miniSGD', acc_test)
np.save('loss_miniSGD', total_loss/no_users)

# %%
# Create plots with pre-defined labels.
fig, ax = plt.subplots()
ax.plot(range(n_epochs), total_loss/no_users, 'r-*', label='Average Loss')

legend = ax.legend(loc='upper right', shadow=True, fontsize='x-large')

plt.yscale('log')
plt.show()
